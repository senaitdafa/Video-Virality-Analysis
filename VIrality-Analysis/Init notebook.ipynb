# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.31.0-py2.py3-none-any.whl (7.8 MB)
# Requirement already satisfied: google-auth-oauthlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (0.4.6)
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting WebTest
#   Downloading WebTest-3.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyOpenSSL in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (20.0.1)
# Collecting statsmodels==0.13.1
#   Downloading statsmodels-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.20.2-py3-none-any.whl (96 kB)
# Collecting uritemplate<5,>=3.0.0
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-python-client->-r ./requirements.txt (line 1)) (1.31.4)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-python-client->-r ./requirements.txt (line 1)) (1.35.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-auth-oauthlib->-r ./requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from google-auth-httplib2->-r ./requirements.txt (line 3)) (1.16.0)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting WebOb>=1.2
#   Downloading WebOb-1.8.7-py2.py3-none-any.whl (114 kB)
# Collecting waitress>=0.8.5
#   Downloading waitress-2.0.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: cryptography>=3.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyOpenSSL->-r ./requirements.txt (line 5)) (3.4.8)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.1->-r ./requirements.txt (line 6)) (1.19.5)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.1->-r ./requirements.txt (line 6)) (1.2.5)
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.1->-r ./requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->-r ./requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: setuptools>=40.3.0 in /root/venv/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (47.1.0)
# Requirement already satisfied: packaging>=14.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (21.2)
# Requirement already satisfied: pytz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (2021.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (2.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0; python_version > "3" in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (3.19.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->-r ./requirements.txt (line 1)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->-r ./requirements.txt (line 1)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->-r ./requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->-r ./requirements.txt (line 2)) (3.1.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cryptography>=3.2->pyOpenSSL->-r ./requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas>=0.25->statsmodels==0.13.1->-r ./requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3.0.0dev,>=1.16.0->google-api-python-client->-r ./requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=3.2->pyOpenSSL->-r ./requirements.txt (line 5)) (2.21)
# Installing collected packages: httplib2, google-auth-httplib2, uritemplate, google-api-python-client, soupsieve, beautifulsoup4, WebOb, waitress, WebTest, patsy, statsmodels
# Successfully installed WebOb-1.8.7 WebTest-3.0.0 beautifulsoup4-4.10.0 google-api-python-client-2.31.0 google-auth-httplib2-0.1.0 httplib2-0.20.2 patsy-0.5.2 soupsieve-2.3.1 statsmodels-0.13.1 uritemplate-4.1.1 waitress-2.0.0
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c08ba799-9470-405c-a983-e2d1c61a1190' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
